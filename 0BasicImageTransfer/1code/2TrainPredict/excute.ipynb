# %%
# !python train.py --cuda --niter 20 --lr_decay_iters 5  --niter_decay 20
# Out:
# Namespace(batch_size=1, beta1=0.5, cuda=True, dataset='JMAG', direction='a2b', epoch_count=1, input_nc=3, lamb=10, lr=0.0002, lr_decay_iters=5, lr_policy='lambda', ndf=64, netG='unet_256', ngf=64, niter=20, niter_decay=20, output_nc=3, seed=123, test_batch_size=1, threads=4)
# ===> Loading datasets
# ===> Building models
# initialize network with normal
# initialize network with normal
# ===> Epoch[1](1/3436): Loss_D: 2.1456 Loss_G: 25.4645
# ===> Epoch[1](2/3436): Loss_D: 12.7610 Loss_G: 14.3883
# ===> Epoch[1](3/3436): Loss_D: 3.1575 Loss_G: 12.6078
# ===> Epoch[1](4/3436): Loss_D: 3.9489 Loss_G: 10.2117
# ===> Epoch[1](5/3436): Loss_D: 1.2910 Loss_G: 9.5381
# ===> Epoch[1](6/3436): Loss_D: 0.9823 Loss_G: 9.8376
# ===> Epoch[1](7/3436): Loss_D: 0.8250 Loss_G: 9.4671
# ===> Epoch[1](8/3436): Loss_D: 0.5708 Loss_G: 9.1938
# ===> Epoch[1](9/3436): Loss_D: 0.5731 Loss_G: 9.1298
# ===> Epoch[1](10/3436): Loss_D: 0.5935 Loss_G: 8.5185
# ...

# %%
# !python test.py --dataset JMAG --cuda
# Out:
# Namespace(cuda=True, dataset='facades', direction='b2a', nepochs=200)
# Image saved as result/facades/cmp_x0086.png
# Image saved as result/facades/cmp_x0117.png
# Image saved as result/facades/cmp_x0186.png
# Image saved as result/facades/cmp_x0197.png
# Image saved as result/facades/cmp_b0125.png
# Image saved as result/facades/cmp_b0026.png
# Image saved as result/facades/cmp_x0157.png
# Image saved as result/facades/cmp_x0046.png
# Image saved as result/facades/cmp_b0280.png
# Image saved as result/facades/cmp_b0242.png
# Image saved as result/facades/cmp_b0081.png
# Image saved as result/facades/cmp_x0183.png
# Image saved as result/facades/cmp_x0003.png
# Image saved as result/facades/cmp_b0047.png
# Image saved as result/facades/cmp_b0206.png
# Image saved as result/facades/cmp_x0119.png
# Image saved as result/facades/cmp_b0260.png
# Image saved as result/facades/cmp_b0192.png
# Image saved as result/facades/cmp_b0013.png
# Image saved as result/facades/cmp_x0169.png
# ...

# %%
import time
t = time.time()
# !python test.py --dataset JMAG --cuda
elapsed = time.time() - t
# Out:
# Namespace(cuda=True, dataset='JMAG', direction='a2b', nepochs=160)
# Image saved as result/JMAG/2167_trans.jpg
# Image saved as result/JMAG/1238_trans.jpg
# Image saved as result/JMAG/2058_trans.jpg
# Image saved as result/JMAG/1916_trans.jpg
# Image saved as result/JMAG/2943_trans.jpg
# Image saved as result/JMAG/1025_trans.jpg
# Image saved as result/JMAG/2733_trans.jpg
# Image saved as result/JMAG/1534_trans.jpg
# Image saved as result/JMAG/2483_trans.jpg
# Image saved as result/JMAG/2642_trans.jpg
# Image saved as result/JMAG/2288_trans.jpg
# Image saved as result/JMAG/99_trans.jpg
# Image saved as result/JMAG/3329_trans.jpg
# Image saved as result/JMAG/189_trans.jpg
# Image saved as result/JMAG/1828_trans.jpg
# Image saved as result/JMAG/2392_trans.jpg
# Image saved as result/JMAG/2170_trans.jpg
# Image saved as result/JMAG/1064_trans.jpg
# Image saved as result/JMAG/2668_trans.jpg
# Image saved as result/JMAG/774_trans.jpg
# Image saved as result/JMAG/985_trans.jpg
# ...

# %%
print(elapsed/600)
# Out:
# 0.031650032997131344

# %%
0.031650032997131344*600
# Out:
# 18.990019798278805
